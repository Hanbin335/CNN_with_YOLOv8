# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#레이블이 따로 있지 않은 데이터이므로 파일 이름에서 레이블 가져오기
import os
import cv2
import tensorflow as tf
image_path = '/content/drive/MyDrive/dog_emotion/Dog Emotion'
class_names = sorted(os.listdir(image_path))
if 'labels.csv' in class_names:
  class_names.remove('labels.csv')
import numpy as np
img_size = (200 , 200 , 3)
images = []
labels = []

for class_name in class_names:
  class_folder = os.path.join(image_path , class_name)
  if os.path.isdir(class_folder):
    for file_name in os.listdir(class_folder):
      if file_name.endswith('.jpg'):
        img_path = os.path.join(class_folder , file_name)
        #print(img_path)
        img = cv2.imread(img_path)
        if img is not None:
          img_resized = cv2.resize(img , img_size[0 : 2])
          img_cvt_rgb = cv2.cvtColor(img_resized , cv2.COLOR_BGR2RGB)
          images.append(np.asarray(img_cvt_rgb))

          #레이블 원핫 인코딩하기
          label = np.zeros(len(class_names))
          label[class_names.index(class_name)] = 1
          #print(label)
          labels.append(label)
images = np.asarray(images)
labels = np.asarray(labels)

# %%
from sklearn.model_selection import train_test_split
X_train , X_val , y_train , y_val = train_test_split(images , labels , test_size = 0.2)

# %%
class_names
# Out:
# ['angry', 'happy', 'relaxed', 'sad']

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape = img_size),
    tf.keras.layers.Rescaling(scale = 1. / 255),
    tf.keras.layers.Conv2D(64 , kernel_size = 3, padding = 'same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Conv2D(64 , kernel_size = 3, padding = 'same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(pool_size = 2),

    tf.keras.layers.Conv2D(128 , kernel_size = 2, padding = 'same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Conv2D(128 , kernel_size = 2, padding = 'same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(pool_size = 2),

    tf.keras.layers.Conv2D(256 , kernel_size = 2, padding = 'same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Conv2D(256 , kernel_size = 2, padding = 'same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(pool_size = 2),

    tf.keras.layers.Conv2D(512 , kernel_size = 2, padding = 'same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Conv2D(512 , kernel_size = 2, padding = 'same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(pool_size = 2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256 , activation = 'relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(128 , activation = 'relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(64 , activation = 'relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(len(class_names) , activation = 'softmax')
])
model.compile(loss = 'categorical_crossentropy' , optimizer = 'adam' , metrics = ['accuracy'])
early_stopping_cb = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss' , patience = 15)
history = model.fit(X_train , y_train , epochs = 60 , validation_data = (X_val , y_val) , callbacks = [early_stopping_cb])
# Out:
# Epoch 1/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 60s 378ms/step - accuracy: 0.2557 - loss: 6.1761 - val_accuracy: 0.2478 - val_loss: 1.3864
# Epoch 2/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 65s 299ms/step - accuracy: 0.3044 - loss: 1.3764 - val_accuracy: 0.2478 - val_loss: 1.3865
# Epoch 3/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 297ms/step - accuracy: 0.3330 - loss: 1.3054 - val_accuracy: 0.2403 - val_loss: 1.3861
# Epoch 4/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 295ms/step - accuracy: 0.3459 - loss: 1.2784 - val_accuracy: 0.2843 - val_loss: 1.3789
# Epoch 5/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 295ms/step - accuracy: 0.3658 - loss: 1.2616 - val_accuracy: 0.3673 - val_loss: 1.2892
# Epoch 6/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 301ms/step - accuracy: 0.3825 - loss: 1.2445 - val_accuracy: 0.3069 - val_loss: 1.3811
# Epoch 7/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 295ms/step - accuracy: 0.3662 - loss: 1.2555 - val_accuracy: 0.3799 - val_loss: 1.2888
# Epoch 8/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 300ms/step - accuracy: 0.3563 - loss: 1.2650 - val_accuracy: 0.3937 - val_loss: 1.2451
# Epoch 9/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 295ms/step - accuracy: 0.3805 - loss: 1.2252 - val_accuracy: 0.3887 - val_loss: 1.1974
# Epoch 10/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 301ms/step - accuracy: 0.4178 - loss: 1.2022 - val_accuracy: 0.3711 - val_loss: 1.1995
# Epoch 11/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - accuracy: 0.4310 - loss: 1.1716 - val_accuracy: 0.3673 - val_loss: 1.3207
# Epoch 12/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 294ms/step - accuracy: 0.4366 - loss: 1.1566 - val_accuracy: 0.4050 - val_loss: 1.2123
# Epoch 13/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 300ms/step - accuracy: 0.4494 - loss: 1.1711 - val_accuracy: 0.4050 - val_loss: 1.2748
# Epoch 14/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - accuracy: 0.4548 - loss: 1.1301 - val_accuracy: 0.4491 - val_loss: 1.1620
# Epoch 15/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 294ms/step - accuracy: 0.5181 - loss: 1.0989 - val_accuracy: 0.4566 - val_loss: 1.0971
# Epoch 16/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 295ms/step - accuracy: 0.4713 - loss: 1.0923 - val_accuracy: 0.4038 - val_loss: 1.2336
# Epoch 17/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 294ms/step - accuracy: 0.4704 - loss: 1.1290 - val_accuracy: 0.4264 - val_loss: 1.3183
# Epoch 18/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 299ms/step - accuracy: 0.5281 - loss: 1.0796 - val_accuracy: 0.4579 - val_loss: 1.0949
# Epoch 19/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 294ms/step - accuracy: 0.5184 - loss: 1.0432 - val_accuracy: 0.4704 - val_loss: 1.0708
# Epoch 20/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 299ms/step - accuracy: 0.5542 - loss: 0.9970 - val_accuracy: 0.5484 - val_loss: 1.0487
# Epoch 21/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - accuracy: 0.5564 - loss: 0.9871 - val_accuracy: 0.6428 - val_loss: 0.8633
# Epoch 22/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - accuracy: 0.5907 - loss: 0.9195 - val_accuracy: 0.5509 - val_loss: 1.2921
# Epoch 23/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - accuracy: 0.6406 - loss: 0.8483 - val_accuracy: 0.6138 - val_loss: 0.9358
# Epoch 24/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 299ms/step - accuracy: 0.6545 - loss: 0.8168 - val_accuracy: 0.5836 - val_loss: 0.9706
# Epoch 25/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 294ms/step - accuracy: 0.7197 - loss: 0.7008 - val_accuracy: 0.7824 - val_loss: 0.5941
# Epoch 26/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 294ms/step - accuracy: 0.7358 - loss: 0.6586 - val_accuracy: 0.7648 - val_loss: 0.6036
# Epoch 27/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 299ms/step - accuracy: 0.7428 - loss: 0.6183 - val_accuracy: 0.8126 - val_loss: 0.5190
# Epoch 28/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 293ms/step - accuracy: 0.7842 - loss: 0.5574 - val_accuracy: 0.8692 - val_loss: 0.3616
# Epoch 29/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 294ms/step - accuracy: 0.8139 - loss: 0.4765 - val_accuracy: 0.8843 - val_loss: 0.3230
# Epoch 30/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 300ms/step - accuracy: 0.8299 - loss: 0.4450 - val_accuracy: 0.8616 - val_loss: 0.3937
# Epoch 31/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 293ms/step - accuracy: 0.8548 - loss: 0.3920 - val_accuracy: 0.8805 - val_loss: 0.3224
# Epoch 32/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 298ms/step - accuracy: 0.8787 - loss: 0.3438 - val_accuracy: 0.9283 - val_loss: 0.2162
# Epoch 33/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 294ms/step - accuracy: 0.8852 - loss: 0.3403 - val_accuracy: 0.9371 - val_loss: 0.1839
# Epoch 34/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 298ms/step - accuracy: 0.8966 - loss: 0.3042 - val_accuracy: 0.9182 - val_loss: 0.2250
# Epoch 35/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 295ms/step - accuracy: 0.9029 - loss: 0.2781 - val_accuracy: 0.9572 - val_loss: 0.1236
# Epoch 36/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 299ms/step - accuracy: 0.9175 - loss: 0.2403 - val_accuracy: 0.9547 - val_loss: 0.1613
# Epoch 37/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - accuracy: 0.8985 - loss: 0.2754 - val_accuracy: 0.9132 - val_loss: 0.2510
# Epoch 38/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 293ms/step - accuracy: 0.9198 - loss: 0.2443 - val_accuracy: 0.9333 - val_loss: 0.2014
# Epoch 39/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 295ms/step - accuracy: 0.9320 - loss: 0.2158 - val_accuracy: 0.9786 - val_loss: 0.0684
# Epoch 40/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - accuracy: 0.9400 - loss: 0.1680 - val_accuracy: 0.9836 - val_loss: 0.0655
# Epoch 41/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 300ms/step - accuracy: 0.9384 - loss: 0.1884 - val_accuracy: 0.9912 - val_loss: 0.0516
# Epoch 42/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 294ms/step - accuracy: 0.9478 - loss: 0.1503 - val_accuracy: 0.9874 - val_loss: 0.0392
# Epoch 43/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 299ms/step - accuracy: 0.9576 - loss: 0.1272 - val_accuracy: 0.9950 - val_loss: 0.0371
# Epoch 44/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 294ms/step - accuracy: 0.9501 - loss: 0.1526 - val_accuracy: 0.9786 - val_loss: 0.0660
# Epoch 45/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 299ms/step - accuracy: 0.9506 - loss: 0.1406 - val_accuracy: 0.9899 - val_loss: 0.0499
# Epoch 46/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - accuracy: 0.9405 - loss: 0.2251 - val_accuracy: 0.9912 - val_loss: 0.0446
# Epoch 47/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 299ms/step - accuracy: 0.9395 - loss: 0.1673 - val_accuracy: 0.9660 - val_loss: 0.1001
# Epoch 48/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 299ms/step - accuracy: 0.9571 - loss: 0.1308 - val_accuracy: 0.9723 - val_loss: 0.1129
# Epoch 49/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 293ms/step - accuracy: 0.9502 - loss: 0.1562 - val_accuracy: 0.9950 - val_loss: 0.0175
# Epoch 50/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 300ms/step - accuracy: 0.9628 - loss: 0.1140 - val_accuracy: 0.9761 - val_loss: 0.0901
# Epoch 51/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 293ms/step - accuracy: 0.9618 - loss: 0.1063 - val_accuracy: 0.9950 - val_loss: 0.0331
# Epoch 52/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - accuracy: 0.9568 - loss: 0.1132 - val_accuracy: 0.9698 - val_loss: 0.1276
# Epoch 53/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 300ms/step - accuracy: 0.9494 - loss: 0.1621 - val_accuracy: 0.9962 - val_loss: 0.0307
# Epoch 54/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 293ms/step - accuracy: 0.9649 - loss: 0.1218 - val_accuracy: 0.9887 - val_loss: 0.0421
# Epoch 55/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 299ms/step - accuracy: 0.9678 - loss: 0.1052 - val_accuracy: 0.9874 - val_loss: 0.0375
# Epoch 56/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 294ms/step - accuracy: 0.9698 - loss: 0.1052 - val_accuracy: 0.9824 - val_loss: 0.0705
# Epoch 57/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 299ms/step - accuracy: 0.9536 - loss: 0.1513 - val_accuracy: 0.9912 - val_loss: 0.0270
# Epoch 58/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - accuracy: 0.9596 - loss: 0.1200 - val_accuracy: 0.9635 - val_loss: 0.1329
# Epoch 59/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 293ms/step - accuracy: 0.9779 - loss: 0.0717 - val_accuracy: 0.9987 - val_loss: 0.0069
# Epoch 60/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 294ms/step - accuracy: 0.9765 - loss: 0.0736 - val_accuracy: 0.9497 - val_loss: 0.1630

# %%
history = history.history
loss = history['loss']
val_loss = history['val_loss']
accuracy = history['accuracy']
val_accuracy = history['val_accuracy']

epochs = range(1 , len(loss) + 1)
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 5))

plt.subplot(121)
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(122)
plt.plot(epochs, accuracy, label='Training Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.show()

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)              │ (None, 200, 200, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 200, 200, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 200, 200, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_8 (Activation)            │ (None, 200, 200, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 200, 200, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 200, 200, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_9 (Activation)            │ (None, 200, 200, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 100, 100, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 100, 100, 128)       │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_10               │ (None, 100, 100, 128)       │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_10 (Activation)           │ (None, 100, 100, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 100, 100, 128)       │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_11               │ (None, 100, 100, 128)       │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_11 (Activation)           │ (None, 100, 100, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 50, 50, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 50, 50, 256)         │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 50, 50, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_12 (Activation)           │ (None, 50, 50, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 50, 50, 256)         │         262,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_13               │ (None, 50, 50, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_13 (Activation)           │ (None, 50, 50, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 25, 25, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 25, 25, 512)         │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_14               │ (None, 25, 25, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_14 (Activation)           │ (None, 25, 25, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_15 (Conv2D)                   │ (None, 25, 25, 512)         │       1,049,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_15               │ (None, 25, 25, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_15 (Activation)           │ (None, 25, 25, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 12, 12, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 73728)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 256)                 │      18,874,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 4)                   │             260 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 63,078,158 (240.62 MB)
#  Trainable params: 21,024,772 (80.20 MB)
#  Non-trainable params: 3,840 (15.00 KB)
#  Optimizer params: 42,049,546 (160.41 MB)

# %%
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

test_image_path = '/content/drive/MyDrive/happydog.jpg'
#이미지 로드 및 전처리
def load_and_preprocess_image(image_path, target_size):
    img = cv2.imread(image_path)
    if img is None:
        raise ValueError("이미지 Error.")
    img_resized = cv2.resize(img, target_size[:2])
    img_rgb = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)
    img_array = np.asarray(img_rgb)
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

target_size = (200, 200)
test_img_array = load_and_preprocess_image(test_image_path, target_size)

predictions = model.predict(test_img_array)
predicted_class = np.argmax(predictions, axis=1)[0]

class_names = sorted(os.listdir(image_path))
if 'labels.csv' in class_names:
    class_names.remove('labels.csv')
    class_names.remove('real_final_dog_emotion.keras')
predicted_class_name = class_names[predicted_class]

plt.figure(figsize=(6, 6))
plt.imshow(test_img_array[0].astype('uint8'))
plt.title(f'Predicted Class: {predicted_class_name}')
plt.axis('off')
plt.show()
print(predictions * 100)
print(class_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[4.2658535e+01 5.6852043e+01 3.6072776e-02 4.5335585e-01]]
# ['angry', 'happy', 'relaxed', 'sad']

# %%
import cv2
from ultralytics import YOLO
import tensorflow as tf
import numpy as np

detection_model = YOLO('yolov8s.pt')
prediction_model = tf.keras.models.load_model('C:\\Users\\godha\\Desktop\\myjob\\phyon\\dog_emotion\\Dog Emotion\\real_final_dog_emotion.keras')

cap = cv2.VideoCapture('C:\\Users\\godha\\Desktop\\myjob\\phyon\\dog_emotion\\Dog Emotion\\in\\happydog.mp4')

while cap.isOpened():
    
    ret , frame = cap.read()

    if not ret:
        break

    results = detection_model.predict(frame , conf = 0.3)

    dog_class_id = 16
    dog_boxes = []
    filtered_results = []
    for result in results:
        for box in result.boxes:
            if box.cls == dog_class_id:
                dog_boxes.append(box)

    if dog_boxes:
        for box in dog_boxes:
            x1 , y1 , x2 , y2 = map(int , box.xyxy[0])
            crop = frame[y1 : y2 , x1 : x2]
            resized_crop = cv2.resize(crop , (200 , 200))
            data = np.expand_dims(resized_crop , axis = 0)
            prediction = prediction_model.predict(data)
            prediction_argmax = np.argmax(prediction)
            emotion_label = ['Angry' , 'Happy' , 'Relaxed' , 'Sad']
            emotion = emotion_label[prediction_argmax]

            cv2.putText(frame , emotion , (x1 + 15 , y1 + 25) , cv2.FONT_HERSHEY_COMPLEX , 0.9, (255, 0, 0), 2)
            cv2.rectangle(frame , (x1 , y1) , (x2 , y2) , (0 , 255 , 0) , 2)
    cv2.imshow('video' , frame)

    
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
